# %%
#simple function
def add():
    print("calling from add")
add()
# Out:
# calling from add

# %%
# function with retuen
def add():
    c="calling return workes"
    return c
print(add())
# Out:
# calling return workes

# %%
#lambda functions:
ad=lambda a,b:a+b 
print(ad(2,2))
# Out:
# 4
