# %%
print("welcom to new learning program")
# Out:
# welcom to new learning program

# %%
#if loop  
a=10
print(a)
# Out:
# 10

# %%
for i in range(7):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
age =32+12+\
22+100
print(age)
# Out:
# 166

# %%
# multiple statement on single line
x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
# variable assignment
age=32
name='somling'
print(type(age))
print(type('somling'))
# Out:
# <class 'int'>
# <class 'str'>

# %%
#assignment ==
b=10
a=b
print(b)
# Out:
# 10

# %%
#FOR LOOP
for i in range(1,11,2): #parameters = start , stop-1,inc/dec
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
a=int(input("enter 1 st no:"))
b=int(input("enter 2 nd no:"))
c=input("choose operatore")
if (c=='+'):
    print("addition=",a+b)
elif(c=='-'):
    print("substraction=",a-b)
elif(c=='%'):
    print("module=",a%b)
elif(c=='/'):
    print(a/b)
else:

    print("wrong i/p")
# Out:
# 1.5
